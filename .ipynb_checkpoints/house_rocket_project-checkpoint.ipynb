# %% [markdown]
# # House Rockets

# %% [markdown]
# Dataset de : https://www.kaggle.com/datasets/harlfoxem/housesalesprediction

# %% [markdown]
# # Questão de Negócio
# A House Rocket é uma plataforma digital que tem como modelo de negócio, a compra e a venda de imóveis usando tecnologia. Sua principal estratégia é comprar boas casas em ótimas localizações com preços baixos e depois revendê-las posteriormente à preços mais altos. Quanto maior a diferença entre a compra e a venda, maior o lucro da empresa e portanto maior sua receita.
#
# Entretanto, as casas possuem muitos atributos que as tornam mais ou menos atrativas aos compradores e vendedores e a localização e o período do ano também podem influenciar os preços. A seguir vamos responder as seguintes perguntas:
#
# ### 1. Quais são os imóveis que a House Rocket deveria comprar e por qual preço ?
# ### 2. Uma vez a casa comprada, qual o melhor momento para vendê-las e por qual preço ?

# %% [markdown]
# # Importação dos Dados

# %%
# importando bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# carregando a base de dados
data = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# # Visualização dos Dados

# %%
display(data)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.describe().round(3)
# Out:
#                  id        price   bedrooms  bathrooms  sqft_living  \
# count  2.161300e+04    21613.000  21613.000  21613.000    21613.000
# mean   4.580302e+09   540088.142      3.371      2.115     2079.900
# std    2.876566e+09   367127.196      0.930      0.770      918.441
# min    1.000102e+06    75000.000      0.000      0.000      290.000
# 25%    2.123049e+09   321950.000      3.000      1.750     1427.000
# 50%    3.904930e+09   450000.000      3.000      2.250     1910.000
# 75%    7.308900e+09   645000.000      4.000      2.500     2550.000
# max    9.900000e+09  7700000.000     33.000      8.000    13540.000
#
#           sqft_lot     floors  waterfront       view  condition      grade  \
# count    21613.000  21613.000   21613.000  21613.000  21613.000  21613.000
# mean     15106.968      1.494       0.008      0.234      3.409      7.657
# std      41420.512      0.540       0.087      0.766      0.651      1.175
# min        520.000      1.000       0.000      0.000      1.000      1.000
# 25%       5040.000      1.000       0.000      0.000      3.000      7.000
# 50%       7618.000      1.500       0.000      0.000      3.000      7.000
# 75%      10688.000      2.000       0.000      0.000      4.000      8.000
# max    1651359.000      3.500       1.000      4.000      5.000     13.000
#
#        sqft_above  sqft_basement   yr_built  yr_renovated    zipcode  \
# count   21613.000      21613.000  21613.000     21613.000  21613.000
# mean     1788.391        291.509   1971.005        84.402  98077.940
# std       828.091        442.575     29.373       401.679     53.505
# min       290.000          0.000   1900.000         0.000  98001.000
# 25%      1190.000          0.000   1951.000         0.000  98033.000
# 50%      1560.000          0.000   1975.000         0.000  98065.000
# 75%      2210.000        560.000   1997.000         0.000  98118.000
# max      9410.000       4820.000   2015.000      2015.000  98199.000
#
#              lat       long  sqft_living15  sqft_lot15
# count  21613.000  21613.000      21613.000   21613.000
# mean      47.560   -122.214       1986.552   12768.456
# std        0.139      0.141        685.391   27304.180
# min       47.156   -122.519        399.000     651.000
# 25%       47.471   -122.328       1490.000    5100.000
# 50%       47.572   -122.230       1840.000    7620.000
# 75%       47.678   -122.125       2360.000   10083.000
# max       47.778   -121.315       6210.000  871200.000

# %% [markdown]
# # Tranformação dos dados

# %%
#Transformando o tipo da coluna data
data['date'] = pd.to_datetime(data['date'], format="%Y/%m/%d")

# %%
#criando colunas para mês e ano
data['month'] = data['date'].apply(lambda date: date.month)  #coluna de mes
data['year'] = data['date'].apply(lambda date: date.year)  #coluna ano

#vendo as novas colunas
data.head(1)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3        1.0         1180
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  month  \
# 0             0    98178  47.5112 -122.257           1340        5650     10
#
#    year
# 0  2014
#
# [1 rows x 23 columns]

# %%
#coluna com potencial outlier
sns.scatterplot(data=data, x='sqft_lot', y='bedrooms')
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='bedrooms'>

# %%
#coluna com potencial outlier
sns.scatterplot(data=data, x='sqft_lot', y='price')
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
#outliers identificados nos gráficos acima
data.loc[(data['bedrooms'] == 33) |
         (data['sqft_lot'] == 1651359.000)]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 1719   1020069017 2015-03-27  700000.0         4       1.00         1300
# 15870  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 1719    1651359     1.0           0     3  ...              0      1920
# 15870      6000     1.0           0     0  ...            580      1947
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1719              0    98022  47.2313 -122.023           2560      425581
# 15870             0    98103  47.6878 -122.331           1330        4700
#
#        month  year
# 1719       3  2015
# 15870      6  2014
#
# [2 rows x 23 columns]

# %%
#tratando outliers
outlier = data.loc[data['bedrooms'] > 15]
data = data.drop(labels=[15870, 1719], axis=0)

# %% [markdown]
# ## Repondendo a primeira questão de negócio:
# 1. Quais são os imóveis que a House Rocket deveria comprar?

# %%
#descobrindo a mediana de preço por região
median_per_zipcode = data[['zipcode',
                           'price']].groupby('zipcode').median().reset_index()
median_per_zipcode.columns = ['zipcode', 'median price']
display(median_per_zipcode)
# Out:
#     zipcode  median price
# 0     98001      260000.0
# 1     98002      235000.0
# 2     98003      267475.0
# 3     98004     1150000.0
# 4     98005      765475.0
# ..      ...           ...
# 65    98177      554000.0
# 66    98178      278277.0
# 67    98188      264000.0
# 68    98198      265000.0
# 69    98199      689800.0
#
# [70 rows x 2 columns]

# %%
# juntando os dataframes
df = pd.merge(data, median_per_zipcode, how='outer')

# %%
# imóveis que deveria comprar ==> imóveis com valor menor que a mediana da região, condição >=3 e nota >= 8
df = df[['id', 'price', 'zipcode', 'grade', 'median price', 'condition']]
best_houses = df[(df['price'] < df['median price']) & 
                 (df['condition'] >= 3) &
                 (df['grade'] >= 8)]
best_houses
# Out:
#                id      price  zipcode  grade  median price  condition
# 29     3810000860   240000.0    98178      8      278277.0          3
# 172    3348401490   265000.0    98178      8      278277.0          3
# 306    3992700036   415000.0    98125      8      425000.0          3
# 321    1160000115   401000.0    98125      8      425000.0          3
# 322    6161000015   349950.0    98125      8      425000.0          3
# ...           ...        ...      ...    ...           ...        ...
# 21595  3262300920  1200000.0    98039      8     1892500.0          3
# 21598  3025300225  1450000.0    98039      9     1892500.0          4
# 21599  2470200020  1880000.0    98039     10     1892500.0          4
# 21603  5427100150  1410000.0    98039      9     1892500.0          3
# 21610  3262300818  1865000.0    98039     11     1892500.0          3
#
# [2815 rows x 6 columns]

# %%
#arquivo csv com as melhores casas
best_houses.to_csv(r'C:\Users\Rodrigo\AULA FC\Analise de dados\Aulas curso Python do 0 ao DS\Módulo 1\Projeto House Rockets\Best_Houses.csv', index=False, sep = ';')

# %% [markdown]
# ## Repondendo a segunda questão de negócio:
# 2. Uma vez a casa comprada, qual o melhor momento para vendê-las e por qual preço ?

# %%
#descobrindo a melhor época do ano para vender imóvel

avg_price_per_month = data[['month', 'price']].groupby('month').mean('price').reset_index()
sns.lineplot(data=avg_price_per_month,
              x='month',
              y='price')
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
#descobrindo a mediana do preço por região e período do ano
colunas = data[['month', 'zipcode', 'price']].copy()
month_zipcode = colunas.groupby(['zipcode', 'month']).median().reset_index()
month_zipcode.columns = ['zipcode', 'month', 'reference price']

#considerando apenas os melhores meses para venda (4 - 6)
month_zipcode = month_zipcode[(month_zipcode["month"] >= 4)
                              & (month_zipcode['month'] <= 6)]
month_zipcode = month_zipcode.groupby('zipcode').mean().reset_index()
month_zipcode = month_zipcode.drop(columns=['month'])

month_zipcode.head()  #descobrimos a referência de preço para cada região no melhor período de vendas do ano
# Out:
#    zipcode  reference price
# 0    98001     2.716498e+05
# 1    98002     2.369172e+05
# 2    98003     2.731500e+05
# 3    98004     1.224917e+06
# 4    98005     7.704333e+05

# %%
best_houses = pd.merge(best_houses, month_zipcode, how='outer')
best_houses.head(20)
# Out:
#               id     price  zipcode  grade  median price  condition  \
# 0   3.810001e+09  240000.0    98178    8.0      278277.0        3.0
# 1   3.348401e+09  265000.0    98178    8.0      278277.0        3.0
# 2   3.992700e+09  415000.0    98125    8.0      425000.0        3.0
# 3   1.160000e+09  401000.0    98125    8.0      425000.0        3.0
# 4   6.161000e+09  349950.0    98125    8.0      425000.0        3.0
# 5   2.926049e+09  384400.0    98125    8.0      425000.0        3.0
# 6   2.926049e+09  400000.0    98125    8.0      425000.0        3.0
# 7   6.413100e+09  369950.0    98125    8.0      425000.0        3.0
# 8   3.448000e+09  354901.0    98125    8.0      425000.0        3.0
# 9   2.126049e+09  399000.0    98125    8.0      425000.0        3.0
# 10  1.787600e+09  396500.0    98125    8.0      425000.0        3.0
# 11  3.822200e+09  380000.0    98125    8.0      425000.0        3.0
# 12  8.200000e+08  401000.0    98125    8.0      425000.0        3.0
# 13  2.026049e+09  324950.0    98125    8.0      425000.0        3.0
# 14  2.026049e+09  325000.0    98125    8.0      425000.0        3.0
# 15  7.508700e+09  386500.0    98125    8.0      425000.0        3.0
# 16  1.454100e+09  405000.0    98125    8.0      425000.0        3.0
# 17  9.421500e+09  378000.0    98125    8.0      425000.0        4.0
# 18  9.421500e+09  403500.0    98125    8.0      425000.0        3.0
# 19  8.200000e+08  387500.0    98125    8.0      425000.0        3.0
#
#     reference price
# 0     279733.333333
# 1     279733.333333
# 2     400791.666667
# 3     400791.666667
# 4     400791.666667
# 5     400791.666667
# 6     400791.666667
# 7     400791.666667
# 8     400791.666667
# 9     400791.666667
# 10    400791.666667
# 11    400791.666667
# 12    400791.666667
# 13    400791.666667
# 14    400791.666667
# 15    400791.666667
# 16    400791.666667
# 17    400791.666667
# 18    400791.666667
# 19    400791.666667

# %%
best_houses['sale price'] = 'NA'

for i in range(len(best_houses)):
    if best_houses.loc[i, 'price'] > best_houses.loc[i, 'reference price']:
        best_houses.loc[i, 'sale price'] = 1.1 * best_houses.loc[i, 'price']

    elif best_houses.loc[i, 'price'] <= best_houses.loc[i, 'reference price']:
        best_houses.loc[i, 'sale price'] = 1.3 * best_houses.loc[i, 'price']

# %%
best_houses
# Out:
#                 id      price  zipcode  grade  median price  condition  \
# 0     3.810001e+09   240000.0    98178    8.0      278277.0        3.0
# 1     3.348401e+09   265000.0    98178    8.0      278277.0        3.0
# 2     3.992700e+09   415000.0    98125    8.0      425000.0        3.0
# 3     1.160000e+09   401000.0    98125    8.0      425000.0        3.0
# 4     6.161000e+09   349950.0    98125    8.0      425000.0        3.0
# ...            ...        ...      ...    ...           ...        ...
# 2812  2.470200e+09  1880000.0    98039   10.0     1892500.0        4.0
# 2813  5.427100e+09  1410000.0    98039    9.0     1892500.0        3.0
# 2814  3.262301e+09  1865000.0    98039   11.0     1892500.0        3.0
# 2815           NaN        NaN    98002    NaN           NaN        NaN
# 2816           NaN        NaN    98188    NaN           NaN        NaN
#
#       reference price sale price
# 0        2.797333e+05   312000.0
# 1        2.797333e+05   344500.0
# 2        4.007917e+05   456500.0
# 3        4.007917e+05   441100.0
# 4        4.007917e+05   454935.0
# ...               ...        ...
# 2812     1.641500e+06  2068000.0
# 2813     1.641500e+06  1833000.0
# 2814     1.641500e+06  2051500.0
# 2815     2.369172e+05         NA
# 2816     2.819632e+05         NA
#
# [2817 rows x 8 columns]

# %%
best_houses = best_houses.drop(labels=[2815, 2816], axis=0)

# %%
best_houses.tail()
# Out:
#                 id      price  zipcode  grade  median price  condition  \
# 2810  3.262301e+09  1200000.0    98039    8.0     1892500.0        3.0
# 2811  3.025300e+09  1450000.0    98039    9.0     1892500.0        4.0
# 2812  2.470200e+09  1880000.0    98039   10.0     1892500.0        4.0
# 2813  5.427100e+09  1410000.0    98039    9.0     1892500.0        3.0
# 2814  3.262301e+09  1865000.0    98039   11.0     1892500.0        3.0
#
#       reference price sale price
# 2810        1641500.0  1560000.0
# 2811        1641500.0  1885000.0
# 2812        1641500.0  2068000.0
# 2813        1641500.0  1833000.0
# 2814        1641500.0  2051500.0

# %%
#arquivo csv com as melhores casas e os respectios preços de venda sugeridos
best_houses.to_csv(r'C:\Users\Rodrigo\AULA FC\Analise de dados\Aulas curso Python do 0 ao DS\Módulo 1\Projeto House Rockets\Best_Houses_and_Prices.csv', index=False, sep = ';')
